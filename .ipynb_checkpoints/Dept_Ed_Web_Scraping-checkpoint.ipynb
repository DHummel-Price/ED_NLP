# %% [markdown]
# # Department of Education Press Release Scraping
#
# ### Author: Doug Hummel-Price | Created: February 2020 | Updated: 06.09.20
#
# This notebook contains the code to scrape the Department of Education (ED) press releases. It contains sections to scrape the current Trump administration releases as well as the archived Obama administration releases.

# %%
## Import required libraries 
import requests
import bs4
import re
import pandas as pd
from time import sleep

## Create List of links to the individual press releases from the press release pages that contain 10 releases each.  

root = "https://www.ed.gov/news/press-releases?page="
pages = ["https://www.ed.gov/news/press-releases?"]

## Create a list of all 38 pages of Trump press releases
for item in range(1,38):
    item = str(item)
    item = root + item
    pages.append(item)

## Create an empty list to append links to Trump press releases    
trumplinks = []

## Iterates over the the 38 pages, snagging the individual press release links
for page in pages:

    sleep(.4)                                        ## Pauses for .4 seconds in between requests to not overwhelm the server    
    server_response = requests.get(page)             ## Creates object with the code response 
    print(f'The server response for page {page} is: {server_response}\n') ## Displays the HTTP response code

    ## Parse using BeautifulSoup
    soup = bs4.BeautifulSoup(server_response.text, features="html.parser")
    
    ## Snags all the links on the page
    links = []
    for item in soup.find_all('a'):
        link = item.get('href')
        links.append(link)

    ## Creates a blank list to append the individual press release links to
    presslinks = []
    
    ## Iterates over the links, appending only those that have the proper stem for the individual release pages
    for item in links:
            try:
                length = len(item)
                if item[:21] == '/news/press-releases/':
                    if length >29:
                        if item[21:29] != 'monthly/':
                            presslinks.append(item)
                else:
                    pass 
            except:
                pass 
    
    ## Takes the press links and appends the necessary stem to scrape the page 
    for link in presslinks:        
        newlink = "https://www.ed.gov" + link
        trumplinks.append(newlink)

len(trumplinks)
# Out:
# The server response for page https://www.ed.gov/news/press-releases? is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=1 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=2 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=3 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=4 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=5 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=6 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=7 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=8 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=9 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=10 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=11 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=12 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=13 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=14 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=15 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=16 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=17 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=18 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=19 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=20 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=21 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=22 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=23 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=24 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=25 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=26 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=27 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=28 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=29 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=30 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=31 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=32 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=33 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=34 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=35 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=36 is: <Response [200]>
#
# The server response for page https://www.ed.gov/news/press-releases?page=37 is: <Response [200]>
# 376

# %% [markdown]
# #### Note: Having started this NLP project prior to the pandemic, I originally aimed to compare releases under Trump to those under Obama. The section below pulls the Obama releases, similar to the above.

# %%
## This section pulls the Obama Ed archives

## Create List of links to the individual press releases from the press release pages that contain 10 releases each. 
root = "https://www.ed.gov/news/press-release-archive?page="
pages = ["https://www.ed.gov/news/press-releases-archive?"]

## Create a list of all 38 pages of Trump press releases
for item in range(1,171):
    item = str(item)
    item = root + item
    pages.append(item)
pages

## Create an empty list to append links to Trump press releases  
obamalinks = []

## Iterates over the the pages, snagging the individual press release links
for page in pages:

    server_response = requests.get(page)             ## Creates object with the code response 
    print(f'The server response is: {server_response}\n') ## Displays the HTTP response code 

    ## Parse using BeautifulSoup
    soup = bs4.BeautifulSoup(server_response.text, features="html.parser")

    links = []
    for item in soup.find_all('a'):
        link = item.get('href')
        links.append(link)


    presslinks = []

    for item in links:
            try:
                length = len(item)
                if item[:21] == '/news/press-releases/':
                    if length >29:
                        if item[21:29] != 'monthly/':
                            presslinks.append(item)
                else:
                    pass 
            except:
                pass 

    for link in presslinks:        
        newlink = "https://www.ed.gov" + link
        obamalinks.append(newlink)

len(obamalinks)

# %%
## This cell contains a list of a few sample press releases I used to test and verify my code. 
webpages= ['https://www.ed.gov/news/press-releases/schoolsafetygov-launches-help-educators-administrators-parents-and-law-enforcement-prepare-threats', 
"https://www.ed.gov/news/press-releases/president-trump-proposes-transformative-student-first-budget-return-power-states-limit-federal-control-education",
"https://www.ed.gov/news/press-releases/department-education-awards-grants-modernize-workforce-training",
"https://www.ed.gov/news/press-releases/secretary-devos-approves-new-methodology-providing-student-loan-relief-borrower-defense-applicants",
"https://www.ed.gov/news/press-releases/secretary-devos-joins-parents-students-members-congress-celebrate-15th-anniversary-dcosp",
"https://www.ed.gov/news/press-releases/us-secretary-education-arne-duncan-issues-statement-2008-national-assessment-educational-progress-trend-report"]

# %%
## This cell iterates over the list of indiviual Trump releases, and snags the text
data = []
count = 0

for webpage in trumplinks:
    
    ## Creates base page 
    sleep(.6)
    server_response = requests.get(webpage)             ## Creates object with the code response 
    count += 1
    print(f'Checking Trump release number: {count}\n')
    print(f'The server response is: {server_response}\n') ## Displays the HTTP response code 

    ## Parse using BeautifulSoup
    soup = bs4.BeautifulSoup(server_response.text, features="html.parser")

    ## Snag the title
    title = soup.title.string[:-31]

    subtest = '<div class="field field-name-field-subtitle field-type-text field-label-hidden">'
    datetest = '<div class="field field-name-field-release-date field-type-datetime field-label-hidden">'

    subtitle = []
    date = []

    for item in soup.find_all('div'):
        item = str(item)
        if item[:80] == subtest:
            item = item[134:]
            item = item[:-18]
            subtitle = item          ## Snags the subtitle 
            subtitle = subtitle.replace('<br/><br/>',". ")
        elif item[:88] == datetest:
            date = item[185:195]      ## Snags the date

    def remove_tags(text):
        RE = re.compile(r'<[^>]+>')
        return RE.sub('', text)
    
    image = 0
    
    text = str(soup.find_all(property="content:encoded"))
    
    ## Creates a dichotomous variable showing whether the release includes an image
    if "img " in text:
        image = 1
    text = text[60:]
    text = remove_tags(text)        
    
    metadata = ("Trump",date, image, title, subtitle, text)
    data.append(metadata)
# Out:
# Checking Trump release number: 1
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 2
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 3
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 4
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 5
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 6
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 7
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 8
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 9
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 10
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 11
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 12
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 13
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 14
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 15
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 16
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 17
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 18
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 19
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 20
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 21
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 22
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 23
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 24
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 25
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 26
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 27
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 28
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 29
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 30
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 31
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 32
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 33
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 34
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 35
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 36
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 37
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 38
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 39
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 40
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 41
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 42
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 43
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 44
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 45
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 46
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 47
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 48
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 49
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 50
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 51
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 52
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 53
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 54
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 55
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 56
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 57
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 58
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 59
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 60
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 61
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 62
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 63
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 64
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 65
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 66
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 67
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 68
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 69
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 70
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 71
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 72
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 73
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 74
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 75
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 76
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 77
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 78
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 79
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 80
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 81
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 82
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 83
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 84
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 85
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 86
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 87
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 88
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 89
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 90
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 91
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 92
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 93
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 94
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 95
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 96
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 97
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 98
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 99
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 100
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 101
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 102
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 103
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 104
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 105
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 106
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 107
#
# The server response is: <Response [200]>
# Checking Trump release number: 108
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 109
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 110
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 111
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 112
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 113
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 114
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 115
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 116
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 117
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 118
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 119
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 120
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 121
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 122
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 123
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 124
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 125
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 126
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 127
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 128
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 129
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 130
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 131
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 132
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 133
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 134
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 135
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 136
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 137
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 138
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 139
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 140
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 141
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 142
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 143
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 144
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 145
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 146
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 147
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 148
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 149
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 150
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 151
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 152
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 153
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 154
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 155
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 156
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 157
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 158
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 159
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 160
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 161
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 162
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 163
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 164
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 165
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 166
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 167
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 168
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 169
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 170
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 171
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 172
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 173
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 174
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 175
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 176
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 177
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 178
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 179
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 180
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 181
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 182
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 183
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 184
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 185
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 186
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 187
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 188
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 189
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 190
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 191
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 192
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 193
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 194
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 195
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 196
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 197
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 198
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 199
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 200
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 201
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 202
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 203
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 204
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 205
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 206
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 207
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 208
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 209
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 210
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 211
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 212
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 213
#
# The server response is: <Response [200]>
# Checking Trump release number: 214
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 215
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 216
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 217
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 218
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 219
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 220
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 221
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 222
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 223
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 224
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 225
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 226
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 227
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 228
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 229
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 230
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 231
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 232
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 233
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 234
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 235
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 236
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 237
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 238
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 239
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 240
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 241
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 242
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 243
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 244
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 245
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 246
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 247
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 248
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 249
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 250
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 251
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 252
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 253
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 254
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 255
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 256
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 257
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 258
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 259
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 260
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 261
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 262
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 263
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 264
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 265
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 266
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 267
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 268
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 269
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 270
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 271
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 272
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 273
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 274
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 275
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 276
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 277
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 278
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 279
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 280
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 281
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 282
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 283
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 284
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 285
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 286
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 287
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 288
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 289
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 290
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 291
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 292
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 293
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 294
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 295
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 296
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 297
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 298
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 299
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 300
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 301
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 302
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 303
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 304
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 305
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 306
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 307
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 308
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 309
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 310
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 311
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 312
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 313
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 314
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 315
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 316
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 317
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 318
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 319
#
# The server response is: <Response [200]>
# Checking Trump release number: 320
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 321
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 322
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 323
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 324
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 325
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 326
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 327
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 328
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 329
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 330
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 331
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 332
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 333
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 334
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 335
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 336
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 337
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 338
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 339
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 340
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 341
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 342
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 343
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 344
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 345
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 346
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 347
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 348
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 349
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 350
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 351
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 352
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 353
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 354
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 355
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 356
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 357
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 358
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 359
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 360
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 361
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 362
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 363
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 364
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 365
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 366
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 367
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 368
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 369
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 370
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 371
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 372
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 373
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 374
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 375
#
# The server response is: <Response [200]>
#
# Checking Trump release number: 376
#
# The server response is: <Response [200]>

# %%
## This cell does the same as the above, but for the Obama press releases instead of Trump releases

count = 0

for webpage in obamalinks:
    ## Creates base page 
    server_response = requests.get(webpage)             ## Creates object with the code response (a)
    count += 1
    print(f'Checking Obama release number: {count}\n')
    print(f'The server response is: {server_response}\n') ## Displays the HTTP response code (b)

    ## Parse using BeautifulSoup
    soup = bs4.BeautifulSoup(server_response.text, features="html.parser")
    soup

    ## Snag the title
    title = soup.title.string[:-31]

    ## Snag any subtitle

    subtest = '<div class="field field-name-field-subtitle field-type-text field-label-hidden">'
    datetest = '<div class="field field-name-field-release-date field-type-datetime field-label-hidden">'

    subtitle = []
    date = []

    for item in soup.find_all('div'):
        item = str(item)
        if item[:80] == subtest:
            item = item[134:]
            item = item[:-18]
            subtitle = item
            subtitle = subtitle.replace('<br/><br/>',". ")
        elif item[:88] == datetest:
            date = item[185:195]      

    def remove_tags(text):
        RE = re.compile(r'<[^>]+>')
        return RE.sub('', text)
    
    image = 0
    
    text = str(soup.find_all(property="content:encoded"))
    
    if "img " in text:
        image = 1
    text = text[60:]
    text = remove_tags(text)        

    metadata = ("Obama",date, image, title, subtitle, text)
    data.append(metadata)

# %%
## Turns the list of tuples into a dataframe
datadf = pd.DataFrame(data, columns=["President","Date","Has_Image","Title","Subtitle","Text"])

datadf

# %%
## Count how many images are in all releases
datadf.Has_Image.sum()

# %%
## Saves the Raw HTML corpus
datadf.to_excel("RawHTMLCorpus.xlsx")

# %% [markdown]
# ### The cells below involve testing and applying various ways to clean the html text and turn into to text that can then be preprocessed for NLP

# %%
test9 =">25d"

tostrip = ['>','class="note">','\n','\\n',"ockquote>","\'v class=\"alert alert-info\" style=\"width: 66%;\""]
for item in tostrip:
    test9 = test9.strip(item)
    print(item)
    print(test9)

# %%
datadf1 = datadf

# %%
datadf1 = pd.read_excel("CompleteCorpus.xlsx")

# %%
from datetime import date
import numpy as np
import datetime

# %% [markdown]
# #### The datetime cells below take the date and create a variable for the number of days since the respective president's (first) inauguration

# %%
datadf1["Date"] = [datetime.datetime.strptime(item,'%Y-%m-%d') for item in datadf1.Date]

# %%
oaug = datetime.datetime.strptime("2009-01-20",'%Y-%m-%d')
taug = datetime.datetime.strptime("2017-01-20",'%Y-%m-%d')

diff = taug - oaug

# %%
datadf1["Date"] = [str(item)[0:11] for item in datadf1.Date]
datadf1

# %%
datadf1["Date"] = pd.to_datetime(datadf1["Date"])

# %%
dayseries = []

for Date,Pres in zip(datadf1.Date,datadf1.President):
    if Pres == "Trump":
        dayssince = Date - taug
    else:
        dayssince = Date - oaug
    dayseries.append(int(dayssince.days))    
    

datadf1["Days_since_inaug"] = dayseries

# %% [markdown]
# #### The cells below create binary variables indicating whether a given release was before or after each of the five milestones I chose for my COVID analysis.

# %%
models = ["2020-01-05", "2020-02-02", "2020-02-28", "2020-03-16","2020-04-07"]
modelnames = ["Model_A","Model_B","Model_C","Model_D","Model_E"]

for dat,modnam in zip(models,modelnames):
    moddate = datetime.datetime.strptime(dat,'%Y-%m-%d')
    diff = moddate - taug
    print(f"The dividing line for {modnam} is all days greater than {diff.days}")

# %%
datadf1["Post_Model_A"] = [1 if x > 1080 else 0 for x in datadf1.Days_since_inaug]
datadf1["Post_Model_B"] = [1 if x > 1108 else 0 for x in datadf1.Days_since_inaug]
datadf1["Post_Model_C"] = [1 if x > 1134 else 0 for x in datadf1.Days_since_inaug]
datadf1["Post_Model_D"] = [1 if x > 1151 else 0 for x in datadf1.Days_since_inaug]
datadf1["Post_Model_E"] = [1 if x > 1173 else 0 for x in datadf1.Days_since_inaug]

# %%
## Reorder columns
datadf1 = datadf1[["President","Date","Days_since_inaug","Has_Image","Title","Subtitle","Text"]]
datadf1

# %%
datadf1["Subtitle"] = [str(x) for x in datadf1.Subtitle]

# %%
textstrip = ['class="note">',']','>',"<",]
replacelist = [("$"," $")]

# %%
datadf1["Text"] = [text.replace("$"," $") for text in datadf1.Text]

# %%
striplist= ["<p>","<em>","</em>","</p>","<strong>","</strong>","<h3>","</h3>",
              "<br/>","<br>","</br>","<cite>","</cite>","amp;","[]","[","]"]

for char in striplist:
    datadf1["Subtitle"] = [text.strip(char) for text in datadf1.Subtitle]

# %%
textstrip = ['class="note">',']','>',"<",]
for char in textstrip:
    datadf1["Text"] = [text.strip(char) for text in datadf1.Text]

# %%
datadf1["All_Text"] = datadf1.Title+" "+datadf1.Subtitle+" "+datadf1.Text
datadf1

# %%
datadf1.columns

# %%
datadf1 = datadf1[["Date","Days_since_inaug",'Post_Model_A', 'Post_Model_B', 'Post_Model_C',
       'Post_Model_D', 'Post_Model_E',"Has_Image","All_Text"]]

# %%
datadf1.to_excel("CompleteCorpus_NOT_Preprocessed.xlsx")
